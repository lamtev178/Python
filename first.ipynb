# %%
def summ(x,y):
    return x + y
summ(5, 4)
# Out:
# 9

# %%
x = (1, 2, "a", "b")
type(x)
# Out:
# tuple

# %%
x.append(1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-6a887ece7ede> in <module>
# ----> 1 x.append(1)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
y = [1, "a", 2, "b"]
y.append(3)
for item in y:
    print(item)
# Out:
# 1
# a
# 2
# b
# 3

# %%
type(y)
# Out:
# list

# %%
a = 4
b = 4
print(id(a))
print(id(b))
# Out:
# 94753804452576
# 94753804452576

# %%
a is b
# Out:
# True

# %%
x = [1, "a", 2, "b", 3]
x is y
# Out:
# False

# %%
x == y
# Out:
# True

# %%
print(id(x))
x.append("3w")#list is immutable => id doesn't change
print(id(x))
# Out:
# 140184917190048
# 140184917190048

# %%
x = input("Enter number:")
try:
    y = int(x)
except:
    print("It isn't a number")
# Out:
# Enter number:f
# It isn't a number

# %%
print("{1},{0},{2}".format("a","B","C"))
# Out:
# B,a,C

# %%
a = 0
while a < 3 :
    print("A")
    a += 1
# Out:
# A
# A
# A

# %% [markdown]
# Оператор break

# %%
a = 1
while a > 0 :
    if a == 3 :
        break
    a += 1
    print("A")
# Out:
# A
# A

# %% [markdown]
# Оператор continue

# %%
a = 0
while a < 10:
    a += 1
    if a < 7:
        continue
    print("A")
# Out:
# A
# A
# A
# A

# %%
for item in range(4):
    print("B")
# Out:
# B
# B
# B
# B

# %% [markdown]
# # Списки

# %%
a = []
b = list()
c = [1, 2, 3]
type(b)
# Out:
# list

# %%
a = c
c.append(4)#Значение а также меняется, так как list - изменяемый (mutable) тип данных, т.е. и а, и с ссылаются на один и тот же список
a
# Out:
# [1, 2, 31, 41, 4]

# %%
c[2] = 31
a[3] = 41
print(a)
print(c)
# Out:
# [1, 2, 31, 41]
# [1, 2, 31, 41]

# %%
#Добавление элементов в список
a = []
a.append(3)
a.append("Hello")
a
# Out:
# [3, 'Hello']

# %%
a = [3, 'Hello']
a.remove(3)
print(a)
del a[0] 
print(a)
# Out:
# ['Hello']
# []

# %%
a = [1, 2, 3, 4, 5, 6, 7]
print(a[3])
print(a[-1])
print(a[2:4])
# Out:
# 4
# 7
# [3, 4]

# %%
a = [1, 2]
a.insert(0, 5)
a
# Out:
# [5, 1, 2]

# %%
a.remove(1)
a
# Out:
# [5, 2]

# %%
a.clear()
a
# Out:
# []

# %%
a = [1, 2, 3]
b = a.pop(2)
print(a)
print(b)
# Out:
# [1, 2]
# 3

# %%
a.index(2)
# Out:
# 1

# %%
a = [1, 2, 3, 5, 4]
a.sort()
a
# Out:
# [1, 2, 3, 4, 5]

# %%
a.reverse()
a
# Out:
# [5, 4, 3, 2, 1]

# %%
a = [1, 1, 1, 2, 3]
a.count(1)
# Out:
# 3

# %% [markdown]
# ## Абстракция списков

# %%
n = int(input())
a = []

for i in range(n):
    a.append(i)
print(a)
# Out:
# 5
# [0, 1, 2, 3, 4]

# %%
print([i for i in range(int(input()))])
# Out:
# 5
# [0, 1, 2, 3, 4]

# %% [markdown]
# # Словари

# %%
a = dict()
b = {}
c = dict(Ivan = "Manager", Mark = "Programmer")

# %%
a = {"Moscow": "Russia", "USA":"Washington"}
a["China"] = "Beijing"
a
# Out:
# {'Moscow': 'Russia', 'USA': 'Washington', 'China': 'Beijing'}

# %%
a.keys()
# Out:
# dict_keys(['Moscow', 'USA', 'China'])

# %%
a.values()
# Out:
# dict_values(['Russia', 'Washington', 'Beijing'])

# %%
a.items()
# Out:
# dict_items([('Moscow', 'Russia'), ('USA', 'Washington'), ('China', 'Beijing')])

# %% [markdown]
# # Работа с файлами

# %%
f = open("text.txt", "r")
f.read()
# Out:
# 'Привет из файла!'

# %%
f = open("text.txt", "r")
f.read(4)
# Out:
# 'Прив'

# %%
f = open("text.txt", "r")
f.readline()
# Out:
# 'Привет из файла!'

# %%
f.close()

# %%
with open("text.txt", "r") as f:
    for line in f:
        print(line)
# Out:
# Привет из файла!
#
#
#
#
#
# Еще одна строка!

# %%
def func(*args):#Если не знаем сколько будем передавать аргументов - ставим звездочку
    return args

func(2, 3, "Hi", 7)
# Out:
# (2, 3, 'Hi', 7)

# %%
def func(**args):#Если не знаем сколько будем передавать ИМЕНОВАННЫХ аргументов - ставим две звездочки
    return args

func(a = 2, b = 3, c = "Hi", d = 7)
# Out:
# {'a': 2, 'b': 3, 'c': 'Hi', 'd': 7}
